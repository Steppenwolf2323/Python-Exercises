# %% [markdown]
# ## Dictionaries in Python

# %% [markdown]
# ##### 1. Manually create a dictionary, then perform the following basic operations:
# - Add a new key-value pair
# - Update the value of an existing key
# - Print  the value of a specific key

# %%
student_datas = {"name" : "Robert", "age" : 17, "city" : "Dublin"}
print ("The initial dictionary: ", student_datas, "\n")

# adding a couple of new key-value pairs

student_datas["working student"] = False
student_datas["sport"] = "basketball"
print("The second version of the dictionary:" , student_datas, "\n")

# updating a couple of values 

student_datas["age"] = 18
student_datas["working student"] = True
print("The third version of the dictionary:", student_datas, "\n")

# printing a couple of values

print(student_datas["name"], student_datas["age"])
# Out:
# The initial dictionary:  {'name': 'Robert', 'age': 17, 'city': 'Dublin'}
#
# The second version of the dictionary: {'name': 'Robert', 'age': 17, 'city': 'Dublin', 'working student': False, 'sport': 'basketball'}
#
# The third version of the dictionary: {'name': 'Robert', 'age': 18, 'city': 'Dublin', 'working student': True, 'sport': 'basketball'}
#
# Robert 18

# %% [markdown]
# ##### 2. Using the previous dictionary, perform the following operations:
# - Remove a key-value pair
# - Check if a specific key exists in the dictionary
# - Print all keys and values in the dictionary separately

# %%
# remove "sport" from the dictionary

#student_datas.pop("sport")
print(student_datas)
print("\n")

# check if the key "city" and the key "surname" exists

if "city" in student_datas:
    print("'City' is a key in the dict!")
else:
    print("'City' is not a key in the dict!")

if "surname" in student_datas:
    print("'Surname is a key in the dict!")
else:
    print("'Surname is not a key in the dict!")
print("\n")

# print all keys 

for keys in student_datas.keys():
    print(keys, end=' ')

print("\n")

for values in student_datas.values():
    print(values, end=' ')
# Out:
# {'name': 'Robert', 'age': 18, 'city': 'Dublin', 'working student': True}
#
#
# 'City' is a key in the dict!
# 'Surname is not a key in the dict!
#
#
# name age city working student
#
# Robert 18 Dublin True

# %% [markdown]
# ##### 3. Create a dictionary from two lists: one containing keys and the other containing corresponding values.

# %%
list_one = ["Sangiovese", "Aglianico", "Merlot"]
list_two = [12,5,20]

wine_rep = {}
for uno, two in zip(list_one, list_two):
    wine_rep[uno] = two

print(wine_rep)
# Out:
# {'Sangiovese': 12, 'Aglianico': 5, 'Merlot': 20}

# %% [markdown]
# ##### 4. Clean a dictionary by removing all key-value pairs where the value is None.

# %%
wine_rep.clear()
print(wine_rep)
# Out:
# {}

# %% [markdown]
# ##### 5. Merge two dictionaries into one, ensuring that in case of key conflicts, the values from the second dictionary overwrite those from the first.

# %%
dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirty': 20, 'Fourty': 40, 'Fifty': 50}

dict1.update(dict2)

print(dict1)
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 20, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# ##### 6. From a string, the letters become keys and their frequency becomes values in a dictionary.

# %%
long_string = "And they said it was fine to be broken"

frequency_dict= {}

for letter in long_string:
    if letter.lower() not in frequency_dict:
        frequency_dict[letter.lower()] = 1
    else:
        frequency_dict[letter.lower()] += 1

print(frequency_dict)
# Out:
# {'a': 3, 'n': 3, 'd': 2, ' ': 8, 't': 3, 'h': 1, 'e': 4, 'y': 1, 's': 2, 'i': 3, 'w': 1, 'f': 1, 'o': 2, 'b': 2, 'r': 1, 'k': 1}

# %% [markdown]
# ##### 7. From a nested dictionary, extract the value of the innermost dictionary.

# %%
personal_data = {'person': {'name': 'Alice', 'age': 30}}

print(f"The name is {personal_data['person']['name']}, the age is {personal_data['person']['age']}")
# Out:
# The name is Alice, the age is 30

# %% [markdown]
# ##### 8. Create a dictionary with default values for a list of keys.

# %%
employees = ['Kelly', 'Emma', 'Ben']
defaults = {"designation": 'Developer', "salary": 8000}

default_dict = {}
for name in employees:
    default_dict[name] = defaults

print(default_dict)
# Out:
# {'Kelly': {'designation': 'Developer', 'salary': 8000}, 'Emma': {'designation': 'Developer', 'salary': 8000}, 'Ben': {'designation': 'Developer', 'salary': 8000}}

# %% [markdown]
# ##### 9. Create a dictionary from specific keys-value pairs extracted from another dictionary.

# %%
sample_dict = {"name": "Kelly","age": 25,"salary": 8000,"city": "New york"}

# the new dictionary has to contain the followig keys-values pair: name and city

narrowed_dict = {}

for key, value in sample_dict.items():
    if key == "name":
        narrowed_dict[key] = value
    if key == "city":
        narrowed_dict[key] = value


print(narrowed_dict)
# Out:
# {'name': 'Kelly', 'city': 'New york'}

# %% [markdown]
# ##### 10. Sort a dictionary by its values and return a new dictionary with the sorted key-value pairs.

# %%
scores = {'Alice': 88,'Bob': 95,'Charlie': 70,'Diana': 82,'Eve': 91}

scores_sorted = dict(sorted(scores.items(), key=lambda x : x[1], reverse=True))

print(scores_sorted)
# Out:
# {'Bob': 95, 'Eve': 91, 'Alice': 88, 'Diana': 82, 'Charlie': 70}

# %% [markdown]
# ##### 11. Implement a reverse lookup function that takes a dictionary and a value, and returns the first key that corresponds to that value.

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 2}
val_1 = 3
val_2 = 5

def reverse_lookup(straight:dict, val:int):
    
    for key in straight:
        if straight[key] == val:
            return f"'{key}' is the first value of {val} found."
    raise LookupError(f">>> Value of '{val}' not found <<<")
    
print(reverse_lookup(my_dict,val_1))
print(reverse_lookup(my_dict,val_2))
# Out:
# 'c' is the first value of 3 found.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[27], line 13
#      10     raise LookupError(f">>> Value of '{val}' not found <<<")
#      12 print(reverse_lookup(my_dict,val_1))
# ---> 13 print(reverse_lookup(my_dict,val_2))
#
# Cell In[27], line 10, in reverse_lookup(straight, val)
#       8     if straight[key] == val:
#       9         return f"'{key}' is the first value of {val} found."
# ---> 10 raise LookupError(f">>> Value of '{val}' not found <<<")
#
# LookupError: >>> Value of '5' not found <<<

# %% [markdown]
# ##### 12. A dictionary have for different keys, same values. Create a new dictionary that groups keys by their values.

# %%
def invert_key_value(base_dict: dict)-> dict:

    value_key_dict = {}
    for key in base_dict:        
        if base_dict[key] not in value_key_dict:
            value_key_dict[base_dict[key]] = [key]
        else:
            value_key_dict[base_dict[key]].append(key)

    return value_key_dict

base_dict_1 = {'apple': 20, 'banana': 30, 'cherry': 20, 'date': 40, 'elderberry': 30, 'fig': 50, 'grape': 40, 'honeydew': 60, 'kiwi': 50, 'lemon': 20, 'mango': 60, 'nectarine': 30, 'orange': 50, 'papaya': 20, 'quince': 50}
inventory = invert_key_value(base_dict_1)
print(f"Fruits in the storage:\n{inventory}")
print(f"\n")

base_dict_2 = { "Adams": "Client", "Frank": "Director", "Peter": "Manager", "Nichols": "Supplier", "Owen": "Supervisor", "Bill" : "Supervisor", "Baker": "Client", "Carter": "Supplier", "Davis": "Client", "Evans": "Supplier"}
draft_database = invert_key_value(base_dict_2)
print(f"About the shop:\n{draft_database}")
# Out:
# Fruits in the storage:
# {20: ['apple', 'cherry', 'lemon', 'papaya'], 30: ['banana', 'elderberry', 'nectarine'], 40: ['date', 'grape'], 50: ['fig', 'kiwi', 'orange', 'quince'], 60: ['honeydew', 'mango']}
#
#
# About the shop:
# {'Client': ['Adams', 'Baker', 'Davis'], 'Director': ['Frank'], 'Manager': ['Peter'], 'Supplier': ['Nichols', 'Carter', 'Evans'], 'Supervisor': ['Owen', 'Bill']}

# %% [markdown]
# ##### 13. A function open a text file and counts the frequency of each word, storing the results in a dictionary.

# %%
def words_frequency(text:str)-> dict:

    with open(text,"r") as file:
        list_words = file.read().split()

    histogram = {}

    for word in list_words:
        if word not in histogram:
            histogram[word] = 1
        else:
            histogram[word] += 1
    
    return histogram



#word_dict = words_frequency(r"C:\Users\zanca\OneDrive\Desktop\sample.txt")
#for item in word_dict.items():
#    print(item)

# %% [markdown]
# ##### 14. Concatenate two dictionaries, summing the values of common keys. Find the key with the highest value in the resulting dictionary.

# %%
def concatenate_dict(dict_1,dict_2) -> dict:

    new_dict ={}

    for item in dict_1:
        new_dict[item] = dict_1[item]
    
    for pair in dict_2:
        if pair not in new_dict:
            new_dict[pair] = dict_2[pair]
        else:
            new_dict[pair] += dict_2[pair]
    
    sorted_new_dict = sorted(new_dict.items(), key=lambda x: x[1], reverse=True)

    return sorted_new_dict

east = {'a': 2, 'b': 3, 'c': 1}
west = {'a': 4, 'c': 5, 'e': 2} 


res = concatenate_dict(east,west)
for elements in res:
    print(f"Region 'EW', type '{elements[0].upper()}' has a total of {elements[1]} units")
# Out:
# Region 'EW', type 'A' has a total of 6 units
# Region 'EW', type 'C' has a total of 6 units
# Region 'EW', type 'B' has a total of 3 units
# Region 'EW', type 'E' has a total of 2 units

# %% [markdown]
# ##### 15. Create a function that checks if:
# - If the dictionary is empty, return True.
# - all the keys have the same type.
# - all the values have the same type.
# - if the values are lists, check if the elements in the lists have the same type.

# %%
def check_dictionary_consistency(data:dict)-> bool:

    # checking if empty
    if not data:
        print("Empty dictionary")
        return True
    
    # checking the keys
    key_list = []

    for key in data.keys():
        key_list.append(key)

        for element in key_list:
            if type(element) != type(ement[0]):
                print(f"Not all keys are of the same 'type'")
                return False
    else:
        print(f"All keys are of the same type: {type(element)}")

    #checking the values
    value_list = []

    for value in data.values():
        value_list.append(value)

        for item in value_list:
            if type(item) != type(value_list[0]):
                print("Not all values are of the same 'type'")
                return False
    else:
        print(f"All values have the same type: {type(value)}")

    # checking the values inside a value-list

    values_of_value_list = []

    for value in data.values():
        if isinstance(value,list):
            for x in value:
                #print(x,type(x))
                if type(value[0]) != type(x):
                    print("Not all values inside a list are of the same 'type'")
                    return False
    else:
        print(f"The values inside the list are of the same type {type(x)}")

# running some tests

first = {"alice": [85,92,88], "bob": [73, 81],}
second = {"alice":[85,92], 42: [73,81],}
third = {"alice":["A", "B"], "bob": ["73", "81"],}
fourth = {"alice": 2, "bob": "b",}

#check_dictionary_consistency(first)
#check_dictionary_consistency(second)
#check_dictionary_consistency(third)
#check_dictionary_consistency(fourth)
check_dictionary_consistency({})
# Out:
# All keys are of the same type: <class 'str'>
# All values have the same type: <class 'list'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 57
#      53 fourth = {"alice": 2, "bob": "b",}
#      55 #check_dictionary_consistency(first)
#      56 #check_dictionary_consistency(second)
# ---> 57 check_dictionary_consistency(third)
#      58 #check_dictionary_consistency(fourth)
#      59 #check_dictionary_consistency({})
#
# Cell In[75], line 42, in check_dictionary_consistency(data)
#      38 for value in data.values():
#      39     if isinstance(value,list):
#      40         #for x in value:
#      41             #print(x,type(x))
# ---> 42             if type(data[1]) != type(value):
#      43                 print("Not all values inside a list are of the same 'type'")
#      44                 return False
#
# KeyError: 1
